# %% [markdown]
# <a href="https://colab.research.google.com/github/Weddy93/AI-future-directions/blob/main/Copy_of_AI_week6_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1: Edge AI vs Cloud AI — Latency and Privacy
# Edge AI performs AI computations directly on local devices (eg, drones, smartphones, sensors), whereas Cloud AI sends data to remote servers for processing. This difference leads to two major advantages for Edge AI:
#
# 1. Reduced Latency: Since data doesn't need to travel to the cloud and back, decisions can be made in real time. This is critical for time-sensitive applications like autonomous drones, where milliseconds matter for obstacle avoidance or navigation.
# 2. Enhanced Privacy: Sensitive data (e.g., video feeds, biometric inputs) stays on the device, minimizing exposure to breaches or unauthorized access during transmission or storage in the cloud.
# Real-world example — Autonomous Drones:
# - In search-and-rescue missions, drones equipped with Edge AI can analyze terrain, detect humans, and make navigation decisions instantly without relying on cloud connectivity.
# - This ensures faster response times and secure handling of sensitive imagery, especially in remote or disaster-struck areas where connectivity is unreliable.
#
#  Q2: Quantum AI vs Classical AI — Optimization Power
# Classical AI uses traditional computing methods (binary bits) and algorithms like gradient descent or heuristics to solve optimization problems. These methods work well but struggle with combinatorial complexity and local minima traps in large-scale problems.
# Quantum AI, powered by quantum computing, leverages qubits and principles like superposition and entanglement to explore multiple solutions simultaneously. This enables:
# - Exponential speedups in solving problems like the traveling salesman, portfolio optimization, or molecular simulations.
# - Better global optima discovery in complex landscapes.
# Industries poised to benefit most:
# - Logistics: Route optimization, warehouse management, and supply chain coordination.
# - Finance: Risk modeling, fraud detection, and portfolio optimization.
# - Pharmaceuticals: Drug discovery through molecular modeling and protein folding.
# - Energy: Grid optimization and predictive maintenance.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

# Define image size and batch size
IMG_HEIGHT = 180
IMG_WIDTH = 180
BATCH_SIZE = 32

print(f"TensorFlow Version: {tf.__version__}")
print(f"Defined Image Height: {IMG_HEIGHT}, Image Width: {IMG_WIDTH}")
print(f"Defined Batch Size: {BATCH_SIZE}")

# Download and load the tf_flowers dataset
# The 'as_supervised=True' argument loads the dataset as (image, label) pairs.
# The 'with_info=True' argument returns a tfds.core.DatasetInfo object.
(train_ds_raw, val_ds_raw), info = tfds.load(
    'tf_flowers',
    split=['train[:80%]', 'train[80%:]'], # Split the 'train' portion into 80% train and 20% validation
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

num_classes = info.features['label'].num_classes
class_names = info.features['label'].names

print(f"Number of classes: {num_classes}")
print(f"Class names: {class_names}")
print(f"Number of training samples: {tf.data.experimental.cardinality(train_ds_raw).numpy() * BATCH_SIZE}")
print(f"Number of validation samples: {tf.data.experimental.cardinality(val_ds_raw).numpy() * BATCH_SIZE}")
# Out:
# TensorFlow Version: 2.19.0
# Defined Image Height: 180, Image Width: 180
# Defined Batch Size: 32
# WARNING:absl:Variant folder /root/tensorflow_datasets/tf_flowers/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/tf_flowers/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/tf_flowers/incomplete.DUM6VD_3.0.1/tf_flowers-train.tfrecord*...:   0%|   …
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.1. Subsequent calls will reuse this data.
# Number of classes: 5
# Class names: ['dandelion', 'daisy', 'tulips', 'sunflowers', 'roses']
# Number of training samples: 93952
# Number of validation samples: 23488

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Preprocessing function to resize and normalize images
def preprocess_image(image, label):
    image = tf.image.resize(image, (IMG_HEIGHT, IMG_WIDTH))
    image = tf.cast(image, tf.float32) / 255.0 # Normalize to [0, 1]
    return image, label

# Apply preprocessing and configure datasets for performance
train_ds = train_ds_raw.map(preprocess_image, num_parallel_calls=AUTOTUNE)
val_ds = val_ds_raw.map(preprocess_image, num_parallel_calls=AUTOTUNE)

# Configure for performance
train_ds = train_ds.cache().shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

# Verify the number of samples after splitting and before batching for more accurate count
# tf.data.experimental.cardinality returns the number of elements in the dataset, not batches
num_train_samples = info.splits['train'].num_examples * 0.8 # Approx 80% of total train split
num_val_samples = info.splits['train'].num_examples * 0.2 # Approx 20% of total train split

print(f"Processed training dataset has {len(train_ds)} batches, each with {BATCH_SIZE} samples (except possibly the last one).")
print(f"Processed validation dataset has {len(val_ds)} batches, each with {BATCH_SIZE} samples (except possibly the last one).")
print(f"Approximate number of training samples: {int(num_train_samples)}")
print(f"Approximate number of validation samples: {int(num_val_samples)}")
# Out:
# Processed training dataset has 92 batches, each with 32 samples (except possibly the last one).
# Processed validation dataset has 23 batches, each with 32 samples (except possibly the last one).
# Approximate number of training samples: 2936
# Approximate number of validation samples: 734

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2

# 1. Instantiate MobileNetV2 as the base model
# include_top=False removes the classifier layer at the top
# weights='imagenet' loads weights pre-trained on ImageNet
base_model = MobileNetV2(
    input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
    include_top=False,
    weights='imagenet'
)

# Freeze the base model's layers
base_model.trainable = False

# 2. Create a new classification head
# Use Functional API to build the model
inputs = tf.keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
x = base_model(inputs, training=False) # Apply base model in inference mode
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.2)(x) # Add a dropout layer for regularization
outputs = layers.Dense(num_classes, activation='softmax')(x)

# 3. Combine the base model and the new classification head
model = models.Model(inputs, outputs)

# Print model summary to verify the architecture
model.summary()

# 4. Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# Define the number of training epochs
EPOCHS = 10

# 5. Train the compiled model
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds
)

print(f"Model trained for {EPOCHS} epochs.")
# Out:
# /tmp/ipython-input-758348507.py:7: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 6, 6, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         6,405 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,264,389 (8.64 MB)
#  Trainable params: 6,405 (25.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 73s 746ms/step - accuracy: 0.5240 - loss: 1.2390 - val_accuracy: 0.8297 - val_loss: 0.5223
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 76s 690ms/step - accuracy: 0.8211 - loss: 0.5032 - val_accuracy: 0.8651 - val_loss: 0.4185
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 65s 706ms/step - accuracy: 0.8453 - loss: 0.4298 - val_accuracy: 0.8624 - val_loss: 0.3979
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 64s 697ms/step - accuracy: 0.8755 - loss: 0.3614 - val_accuracy: 0.8747 - val_loss: 0.3666
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 72s 788ms/step - accuracy: 0.8861 - loss: 0.3193 - val_accuracy: 0.8651 - val_loss: 0.3552
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 66s 717ms/step - accuracy: 0.9117 - loss: 0.2821 - val_accuracy: 0.8706 - val_loss: 0.3561
# Epoch 7/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 69s 748ms/step - accuracy: 0.9081 - loss: 0.2701 - val_accuracy: 0.8801 - val_loss: 0.3491
# Epoch 8/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 67s 733ms/step - accuracy: 0.9226 - loss: 0.2352 - val_accuracy: 0.8733 - val_loss: 0.3517
# Epoch 9/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 63s 688ms/step - accuracy: 0.9330 - loss: 0.2131 - val_accuracy: 0.8924 - val_loss: 0.3363
# Epoch 10/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 67s 735ms/step - accuracy: 0.9283 - loss: 0.2157 - val_accuracy: 0.8692 - val_loss: 0.3503
# Model trained for 10 epochs.

# %%
import tensorflow as tf

# 1. Instantiate a TFLiteConverter object from the trained model
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 2. Enable default optimizations, which include dynamic range quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# 3. Convert the model to TensorFlow Lite format
tflite_model = converter.convert()

# 4. Save the converted TensorFlow Lite model to a file
with open('flower_classification_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("TensorFlow Lite model saved as 'flower_classification_model.tflite'")
# Out:
# Saved artifact at '/tmp/tmpymjpvxqp'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name='keras_tensor_313')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   135796636859472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633474576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796636859280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633471120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633475152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633476304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633474768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633477456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633477072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633478224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633481296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633480912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633482256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633482064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633483216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633482832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633484176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633483600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633484560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633485136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633483984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633484752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633482448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633484368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796633483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128433744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128433936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128433168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128432592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128432400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128433552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128433360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128432976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128434896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128434320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128434512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128434704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128432208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128435856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128435280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128435472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128435664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128432784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128436816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128436240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128436432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128436624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128434128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128437776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128437200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128437392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128437584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128435088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128438736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128438160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128438352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128438544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128436048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128439696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128439120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128439312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128439504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128437008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128440656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128440080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128440272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128440464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128437968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128441616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128441040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128441232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128441424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128438928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128442576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128442000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128442192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128442384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128439888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128443536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128442960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128443152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128443344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128440848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128444496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128443920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128444112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128444304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128441808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128445456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128444880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128445072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128445264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128442768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128446416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128445840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128446032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128446224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128443728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128447376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128446800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128446992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128447760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128444688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128448336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128447184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128446608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128445648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128448144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796634829840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128447568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127187408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127187024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796128447952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127188752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127187600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127188368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127188560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127188176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127189712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127189136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127189328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127189520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127187792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127190672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127190096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127190288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127190480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127187984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127191632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127191056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127191248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127191440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127188944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127192592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127192016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127192400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127189904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127192976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127193168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127193360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127190864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127194512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127193936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127194128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127194320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127191824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127195472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127195088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127195280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127192784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127196432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127195856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127196048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127196240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127193744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127197392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127196816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127197008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127197200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127194704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127198352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127197776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127197968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127198160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127195664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127199312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127198736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127198928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127199120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127196624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127200272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127199696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127199888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127200080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127197584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127201232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127200656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127200848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127201040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127198544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127202192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127201616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127201808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127202576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127199504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127203152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127202000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127202768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127200464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127202960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127202384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796127201424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126025296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126025488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126024720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126024144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126023952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126025104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126024912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126024528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126026448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126025872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126026064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126026256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126023760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126027408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126026832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126027024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126027216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126024336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126028368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126027792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126027984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126028176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126025680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126029328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126028752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126028944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126029136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126026640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126030288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126030672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135796126030480: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TensorFlow Lite model saved as 'flower_classification_model.tflite'

# %%
import numpy as np
import tensorflow as tf

# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="flower_classification_model.tflite")
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("TFLite model loaded successfully.")
print("Input details:", input_details)
print("Output details:", output_details)
# Out:
# TFLite model loaded successfully.
# Input details: [{'name': 'serving_default_keras_tensor_313:0', 'index': 0, 'shape': array([  1, 180, 180,   3], dtype=int32), 'shape_signature': array([ -1, 180, 180,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall_1:0', 'index': 172, 'shape': array([1, 5], dtype=int32), 'shape_signature': array([-1,  5], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
import numpy as np
import tensorflow as tf

# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="flower_classification_model.tflite")
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("TFLite model loaded successfully.")
print("Input details:", input_details)
print("Output details:", output_details)

# Prepare to evaluate the TFLite model
correct_predictions = 0
total_samples = 0

# Get input and output tensor indexes
input_index = input_details[0]['index']
output_index = output_details[0]['index']

# Iterate through the validation dataset for inference
for images_batch, labels_batch in val_ds:
    for i in range(images_batch.shape[0]):
        img = images_batch[i]
        label = labels_batch[i]

        # TFLite models expect input in a specific format, often float32 and batched.
        # The image is already preprocessed (resized and normalized to [0,1]) and is float32.
        # Add a batch dimension if it's not already there (interpreter expects NCHW or NHWC format).
        input_data = np.expand_dims(img, axis=0).astype(input_details[0]['dtype'])

        # Set the input tensor
        interpreter.set_tensor(input_index, input_data)

        # Invoke the interpreter
        interpreter.invoke()

        # Get the output tensor
        output_data = interpreter.get_tensor(output_index)

        # Get the predicted class (index with highest probability)
        predicted_class = np.argmax(output_data)

        # Compare with true label
        if predicted_class == label.numpy():
            correct_predictions += 1
        total_samples += 1

# Calculate accuracy
accuracy = correct_predictions / total_samples

print(f"\nTotal samples evaluated: {total_samples}")
print(f"Correct predictions: {correct_predictions}")
print(f"TFLite Model Accuracy on Validation Set: {accuracy:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# TFLite model loaded successfully.
# Input details: [{'name': 'serving_default_keras_tensor_313:0', 'index': 0, 'shape': array([  1, 180, 180,   3], dtype=int32), 'shape_signature': array([ -1, 180, 180,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall_1:0', 'index': 172, 'shape': array([1, 5], dtype=int32), 'shape_signature': array([-1,  5], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
#
# Total samples evaluated: 734
# Correct predictions: 645
# TFLite Model Accuracy on Validation Set: 0.8787

# %%
Explain Benefits of Edge AI
 Benefits of Edge AI for Real-time Applications:

1.  Reduced Latency: By performing inference directly on the device (e.g., a smartphone, drone, or industrial sensor) rather than sending data to a remote cloud server, Edge AI drastically reduces the time it takes to get a prediction. For real-time applications like autonomous driving, drone navigation (as mentioned in Q1), or real-time object detection in surveillance, milliseconds matter. Our TFLite model, being lightweight and optimized, can run quickly on edge devices, enabling immediate responses.

2.  Enhanced Privacy and Security: Sensitive data, such as images from security cameras or personal biometric information, can be processed locally on the device. This minimizes the need to transmit data over networks, reducing the risk of data breaches or unauthorized access during transit or storage in the cloud. For a flower classification model, while less sensitive, this principle scales up significantly for applications dealing with private user data.

3.  Lower Bandwidth and Connectivity Costs: Edge AI reduces the amount of data that needs to be sent to the cloud. This saves bandwidth, which can be critical in areas with limited or expensive network access. It also allows applications to function reliably even when offline or in environments with intermittent connectivity, such as remote agricultural fields for crop monitoring or disaster zones for search and rescue.

4.  Increased Reliability: Cloud-dependent AI systems can fail if the internet connection is lost or the cloud service experiences downtime. Edge AI systems can operate independently of constant network connectivity, ensuring continuous operation, which is vital for critical real-time systems like medical devices or industrial control systems.

5.  Lower Power Consumption on Data Transfer: While running AI models on edge devices consumes power, the overall system can be more energy-efficient by avoiding constant data transmission to and from the cloud, especially for devices powered by batteries.

6.  Scalability: Edge AI can enable more devices to participate in an AI ecosystem without overwhelming central cloud servers with massive amounts of raw data. Each edge device handles its own data processing, allowing for distributed and scalable AI deployments.

# %% [markdown]
# TASK2:AI DRIVEN IOT CONCEPT
# key sensors needed are;
#
# Soil Moisture Sensor: Measures water content in the soil to optimize irrigation.
#
# Soil Temperature Sensor: Monitors root-zone temperature, crucial for seed germination and microbial activity.
#
# Soil NPK Sensor: Measures the levels of essential macronutrients: Nitrogen (N), Phosphorus (P), and Potassium (K).
#
# Soil pH Sensor: Monitors soil acidity/alkalinity, which affects nutrient availability.
#
# Leaf Wetness Sensor: Detects moisture on leaf surfaces, helping predict fungal disease outbreaks.
#
# Water pH Sensor: (For irrigation systems) Monitors the pH of the water being used.
#
# Water Flow Sensor: Measures the amount of water used for irrigation.
#
#
#
# Core AI Model: Hybrid Ensemble (LSTM + XGBoost)
#
# a) Temporal Feature Learning with LSTM (Long Short-Term Memory Network)
#
# Purpose: To model time-dependent patterns in the sensor data.
#
# Input: Sequential, time-series data from sensors (soil moisture, temperature, humidity, etc.) over the entire growing season.
#
#
# b) Static & Spatial Feature Integration with XGBoost (Extreme Gradient Boosting)
#
# Purpose: To integrate non-sequential, static, and spatial features.
#
# Input:
#
# Static Features: Soil type, seed variety, historical field yield data.
#
# Spatial Features: Data from multispectral imagery (e.g., NDVI - Normalized Difference Vegetation Index) at different growth stages.
#
# Aggregated LSTM Features: The learned features from the LSTM model's hidden layers can be fed into XGBoost as powerful summary inputs.
#
# +--------------------------------------------------------------------+
# |                  AI-DRIVEN SMART AGRICULTURE SYSTEM                |
# +--------------------------------------------------------------------+
#
# +----------------+      +-----------------+      +-----------------+
# |                |      |                 |      |                 |
# |  SENSOR LAYER  |----->|   EDGE/GATEWAY  |----->|   CLOUD LAYER   |
# |                |      |     LAYER       |      |                 |
# +----------------+      +-----------------+      +-----------------+
#      |  |  |                    |                        |
#      |  |  |                    |                        |
#      v  v  v                    v                        v
# +-----------+             +-------------+          +-------------+
# |Soil       | Wireless    |Data         |   Internet  |Data        |
# |Moisture   |-----------> |Aggregation  |----------> |Storage     |
# +-----------+   (LoRaWAN) +-------------+            +-------------+
# +-----------+                               (Data Lake)  |
# |Temperature|                                            |
# |& Humidity |                                            |
# +-----------+                                            |
# +-----------+                                            |
# |NPK Sensor |                                            v
# +-----------+                                    +-------------+
# +-----------+                                    |AI PROCESSING|
# |Multispectral|                                   +-------------+
# |Camera (Drone)|                                  |             |
# +--------------+                                  | LSTM Model  |
#                                                   |             |
#                                                   +-------------+
#                                                           |
#                                                           v
# +----------------+      +-----------------+      +-------------+
# |                |      |                 |      | PREDICTIONS &|
# |  ACTION LAYER  |<-----|   DASHBOARD     |<-----|   INSIGHTS   |
# |                |      |                 |      |             |
# +----------------+      +-----------------+      +-------------+
#      ^                         ^                        ^
#      |                         |                        |
# +-----------+             +-------------+          +-------------+
# |Smart      |             |Mobile/Web   |          |Yield        |
# |Valves     | Control     |Interface    |          |Prediction   |
# +-----------+  Signals    +-------------+          +-------------+
# +-----------+             |Alerts &     |          |Disease Risk |
# |Fertilizer |             |Notifications|          +-------------+
# |Dispenser  |             +-------------+          |Water Stress |
# +-----------+                                      +-------------+
